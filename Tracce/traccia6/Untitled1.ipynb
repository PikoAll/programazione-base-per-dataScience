# %%
import csv

with open('BankWages.csv','r') as f:
    dataset = list(f.readlines())[1:]
dataset
# Out:
# ['"1","manage",15,"male","no"\n',
#  '"2","admin",16,"male","no"\n',
#  '"3","admin",12,"female","no"\n',
#  '"4","admin",8,"female","no"\n',
#  '"5","admin",15,"male","no"\n',
#  '"6","admin",15,"male","no"\n',
#  '"7","admin",15,"male","no"\n',
#  '"8","admin",12,"female","no"\n',
#  '"9","admin",15,"female","no"\n',
#  '"10","admin",12,"female","no"\n',
#  '"11","admin",16,"female","no"\n',
#  '"12","admin",8,"male","yes"\n',
#  '"13","admin",15,"male","yes"\n',
#  '"14","admin",15,"female","yes"\n',
#  '"15","admin",12,"male","no"\n',
#  '"16","admin",12,"male","no"\n',
#  '"17","admin",15,"male","no"\n',
#  '"18","manage",16,"male","no"\n',
#  '"19","admin",12,"male","no"\n',
#  '"20","admin",12,"female","no"\n',
#  '"21","admin",16,"female","no"\n',
#  '"22","admin",12,"male","yes"\n',
#  '"23","admin",15,"female","yes"\n',
#  '"24","admin",12,"female","yes"\n',
#  '"25","admin",15,"female","yes"\n',
#  '"26","admin",15,"male","no"\n',
#  '"27","manage",19,"male","no"\n',
#  '"28","admin",15,"male","no"\n',
#  '"29","manage",19,"male","no"\n',
#  '"30","admin",15,"male","no"\n',
#  '"31","admin",12,"male","no"\n',
#  '"32","manage",19,"male","no"\n',
#  '"33","admin",15,"male","no"\n',
#  '"34","manage",19,"male","no"\n',
#  '"35","manage",17,"male","no"\n',
#  '"36","admin",8,"female","no"\n',
#  '"37","admin",12,"male","yes"\n',
#  '"38","admin",15,"male","yes"\n',
#  '"39","admin",16,"male","yes"\n',
#  '"40","admin",15,"female","yes"\n',
#  '"41","admin",12,"female","yes"\n',
#  '"42","admin",15,"male","no"\n',
#  '"43","admin",12,"male","no"\n',
#  '"44","admin",8,"male","no"\n',
#  '"45","custodial",12,"male","no"\n',
#  '"46","admin",15,"female","no"\n',
#  '"47","admin",12,"female","no"\n',
#  '"48","custodial",12,"male","no"\n',
#  '"49","admin",15,"male","no"\n',
#  '"50","manage",16,"male","no"\n',
#  '"51","admin",12,"male","no"\n',
#  '"52","admin",15,"male","no"\n',
#  '"53","manage",18,"male","no"\n',
#  '"54","admin",12,"male","no"\n',
#  '"55","admin",12,"male","no"\n',
#  '"56","admin",15,"male","no"\n',
#  '"57","admin",15,"male","no"\n',
#  '"58","admin",15,"female","no"\n',
#  '"59","admin",15,"male","yes"\n',
#  '"60","admin",12,"male","yes"\n',
#  '"61","admin",8,"male","yes"\n',
#  '"62","manage",16,"male","no"\n',
#  '"63","manage",17,"male","no"\n',
#  '"64","manage",16,"male","no"\n',
#  '"65","admin",8,"male","no"\n',
#  '"66","manage",19,"male","no"\n',
#  '"67","manage",16,"male","no"\n',
#  '"68","manage",16,"male","no"\n',
#  '"69","manage",16,"male","no"\n',
#  '"70","admin",15,"male","no"\n',
#  '"71","manage",17,"male","no"\n',
#  '"72","admin",16,"female","no"\n',
#  '"73","admin",12,"female","no"\n',
#  '"74","admin",15,"female","no"\n',
#  '"75","admin",15,"female","no"\n',
#  '"76","admin",15,"female","no"\n',
#  '"77","admin",12,"female","no"\n',
#  '"78","admin",12,"female","no"\n',
#  '"79","admin",16,"female","no"\n',
#  '"80","admin",16,"female","no"\n',
#  '"81","admin",12,"female","no"\n',
#  '"82","admin",12,"female","yes"\n',
#  '"83","admin",12,"female","yes"\n',
#  '"84","admin",8,"female","yes"\n',
#  '"85","admin",15,"male","no"\n',
#  '"86","admin",15,"male","no"\n',
#  '"87","admin",12,"male","no"\n',
#  '"88","manage",19,"male","no"\n',
#  '"89","manage",19,"male","no"\n',
#  '"90","admin",8,"female","no"\n',
#  '"91","admin",12,"female","no"\n',
#  '"92","admin",8,"female","no"\n',
#  '"93","admin",12,"female","no"\n',
#  '"94","admin",12,"female","no"\n',
#  '"95","admin",12,"female","no"\n',
#  '"96","custodial",8,"male","yes"\n',
#  '"97","admin",17,"male","yes"\n',
#  '"98","custodial",8,"male","yes"\n',
#  '"99","admin",12,"female","yes"\n',
#  '"100","manage",18,"male","no"\n',
#  '"101","manage",16,"male","no"\n',
#  '"102","admin",14,"male","no"\n',
#  '"103","manage",19,"male","no"\n',
#  '"104","admin",15,"male","no"\n',
#  '"105","admin",15,"male","no"\n',
#  '"106","manage",19,"male","no"\n',
#  '"107","admin",12,"female","no"\n',
#  '"108","admin",12,"female","no"\n',
#  '"109","admin",12,"male","yes"\n',
#  '"110","admin",15,"male","yes"\n',
#  '"111","custodial",12,"male","yes"\n',
#  '"112","custodial",12,"male","yes"\n',
#  '"113","manage",16,"male","no"\n',
#  '"114","admin",14,"male","no"\n',
#  '"115","admin",15,"male","no"\n',
#  '"116","admin",15,"male","no"\n',
#  '"117","admin",12,"female","no"\n',
#  '"118","admin",12,"female","no"\n',
#  '"119","admin",12,"female","no"\n',
#  '"120","manage",16,"female","no"\n',
#  '"121","admin",15,"female","no"\n',
#  '"122","admin",15,"female","no"\n',
#  '"123","admin",12,"female","no"\n',
#  '"124","admin",16,"female","no"\n',
#  '"125","admin",12,"male","yes"\n',
#  '"126","custodial",15,"male","yes"\n',
#  '"127","custodial",12,"male","yes"\n',
#  '"128","admin",12,"female","yes"\n',
#  '"129","manage",17,"male","no"\n',
#  '"130","manage",20,"male","no"\n',
#  '"131","admin",15,"male","no"\n',
#  '"132","admin",12,"male","no"\n',
#  '"133","admin",15,"male","no"\n',
#  '"134","manage",16,"female","no"\n',
#  '"135","admin",12,"female","no"\n',
#  '"136","admin",12,"male","no"\n',
#  '"137","manage",21,"male","no"\n',
#  '"138","admin",12,"male","no"\n',
#  '"139","admin",8,"female","no"\n',
#  '"140","admin",12,"female","no"\n',
#  '"141","admin",15,"female","no"\n',
#  '"142","admin",12,"female","no"\n',
#  '"143","admin",12,"female","no"\n',
#  '"144","admin",8,"female","no"\n',
#  '"145","admin",12,"male","yes"\n',
#  '"146","admin",18,"male","yes"\n',
#  '"147","admin",15,"male","yes"\n',
#  '"148","admin",15,"female","yes"\n',
#  '"149","admin",12,"male","no"\n',
#  '"150","admin",12,"male","no"\n',
#  '"151","manage",16,"male","no"\n',
#  '"152","custodial",8,"male","no"\n',
#  '"153","admin",12,"female","no"\n',
#  '"154","admin",12,"female","no"\n',
#  '"155","admin",15,"male","yes"\n',
#  '"156","admin",15,"male","yes"\n',
#  '"157","admin",12,"female","yes"\n',
#  '"158","admin",12,"female","yes"\n',
#  '"159","admin",16,"female","yes"\n',
#  '"160","manage",16,"male","no"\n',
#  '"161","admin",16,"male","no"\n',
#  '"162","manage",16,"male","no"\n',
#  '"163","admin",15,"male","no"\n',
#  '"164","admin",15,"female","no"\n',
#  '"165","admin",15,"female","no"\n',
#  '"166","admin",12,"female","no"\n',
#  '"167","admin",12,"female","no"\n',
#  '"168","manage",16,"female","no"\n',
#  '"169","admin",12,"male","yes"\n',
#  '"170","admin",12,"male","yes"\n',
#  '"171","admin",12,"male","yes"\n',
#  '"172","admin",15,"female","yes"\n',
#  '"173","manage",20,"male","no"\n',
#  '"174","custodial",8,"male","no"\n',
#  '"175","admin",8,"male","no"\n',
#  '"176","admin",16,"female","no"\n',
#  '"177","admin",12,"female","no"\n',
#  '"178","admin",12,"female","no"\n',
#  '"179","admin",12,"male","yes"\n',
#  '"180","admin",12,"female","yes"\n',
#  '"181","admin",12,"female","yes"\n',
#  '"182","admin",12,"female","yes"\n',
#  '"183","admin",15,"male","no"\n',
#  '"184","admin",15,"male","no"\n',
#  '"185","custodial",8,"male","no"\n',
#  '"186","admin",15,"male","no"\n',
#  '"187","manage",16,"male","no"\n',
#  '"188","admin",12,"female","no"\n',
#  '"189","admin",12,"female","no"\n',
#  '"190","admin",8,"female","no"\n',
#  '"191","admin",12,"female","no"\n',
#  '"192","admin",12,"male","yes"\n',
#  '"193","admin",12,"female","yes"\n',
#  '"194","admin",15,"female","yes"\n',
#  '"195","admin",12,"female","yes"\n',
#  '"196","admin",16,"female","yes"\n',
#  '"197","manage",15,"male","no"\n',
#  '"198","manage",19,"male","no"\n',
#  '"199","manage",16,"male","no"\n',
#  '"200","manage",17,"male","no"\n',
#  '"201","admin",12,"male","no"\n',
#  '"202","admin",15,"male","no"\n',
#  '"203","admin",12,"male","no"\n',
#  '"204","admin",15,"male","no"\n',
#  '"205","manage",16,"male","no"\n',
#  '"206","custodial",12,"male","no"\n',
#  '"207","admin",15,"male","no"\n',
#  '"208","admin",12,"female","no"\n',
#  '"209","admin",8,"female","no"\n',
#  '"210","admin",15,"male","yes"\n',
#  '"211","admin",15,"male","yes"\n',
#  '"212","admin",15,"male","yes"\n',
#  '"213","custodial",8,"male","yes"\n',
#  '"214","admin",12,"female","yes"\n',
#  '"215","admin",12,"female","yes"\n',
#  '"216","admin",15,"male","no"\n',
#  '"217","admin",16,"male","no"\n',
#  '"218","admin",15,"male","no"\n',
#  '"219","admin",12,"male","no"\n',
#  '"220","admin",12,"male","no"\n',
#  '"221","admin",12,"female","no"\n',
#  '"222","admin",15,"female","no"\n',
#  '"223","admin",8,"female","no"\n',
#  '"224","admin",12,"female","no"\n',
#  '"225","admin",15,"female","no"\n',
#  '"226","admin",16,"female","no"\n',
#  '"227","admin",12,"female","no"\n',
#  '"228","admin",15,"female","no"\n',
#  '"229","admin",12,"female","no"\n',
#  '"230","admin",15,"male","yes"\n',
#  '"231","manage",16,"male","no"\n',
#  '"232","manage",19,"male","no"\n',
#  '"233","admin",15,"male","no"\n',
#  '"234","admin",15,"male","no"\n',
#  '"235","manage",19,"male","no"\n',
#  '"236","admin",8,"female","no"\n',
#  '"237","admin",12,"female","no"\n',
#  '"238","admin",12,"female","no"\n',
#  '"239","admin",12,"female","no"\n',
#  '"240","manage",16,"female","no"\n',
#  '"241","admin",8,"female","no"\n',
#  '"242","admin",12,"female","no"\n',
#  '"243","admin",12,"female","no"\n',
#  '"244","admin",8,"female","no"\n',
#  '"245","admin",12,"female","no"\n',
#  '"246","admin",12,"female","no"\n',
#  '"247","admin",12,"female","no"\n',
#  '"248","admin",12,"female","no"\n',
#  '"249","admin",12,"female","no"\n',
#  '"250","admin",15,"female","no"\n',
#  '"251","admin",12,"female","no"\n',
#  '"252","admin",12,"male","yes"\n',
#  '"253","admin",8,"female","yes"\n',
#  '"254","manage",18,"male","no"\n',
#  '"255","custodial",12,"male","no"\n',
#  '"256","manage",19,"male","no"\n',
#  '"257","manage",19,"male","no"\n',
#  '"258","admin",8,"male","no"\n',
#  '"259","admin",12,"female","no"\n',
#  '"260","admin",12,"female","no"\n',
#  '"261","admin",12,"female","no"\n',
#  '"262","admin",12,"female","no"\n',
#  '"263","admin",12,"female","no"\n',
#  '"264","admin",12,"female","no"\n',
#  '"265","admin",12,"female","no"\n',
#  '"266","admin",16,"female","no"\n',
#  '"267","admin",12,"female","no"\n',
#  '"268","admin",12,"male","yes"\n',
#  '"269","admin",15,"male","no"\n',
#  '"270","admin",15,"male","no"\n',
#  '"271","admin",15,"male","no"\n',
#  '"272","admin",18,"male","no"\n',
#  '"273","custodial",12,"male","no"\n',
#  '"274","manage",16,"male","no"\n',
#  '"275","admin",12,"male","no"\n',
#  '"276","manage",16,"male","no"\n',
#  '"277","manage",16,"female","no"\n',
#  '"278","admin",8,"female","no"\n',
#  '"279","admin",12,"female","no"\n',
#  '"280","admin",12,"female","no"\n',
#  '"281","custodial",8,"male","yes"\n',
#  '"282","admin",14,"male","yes"\n',
#  '"283","manage",19,"male","no"\n',
#  '"284","manage",19,"male","no"\n',
#  '"285","custodial",8,"male","no"\n',
#  '"286","manage",15,"male","no"\n',
#  '"287","admin",16,"male","no"\n',
#  '"288","manage",15,"male","no"\n',
#  '"289","manage",17,"male","no"\n',
#  '"290","manage",18,"male","no"\n',
#  '"291","custodial",12,"male","no"\n',
#  '"292","admin",14,"male","no"\n',
#  '"293","admin",15,"male","no"\n',
#  '"294","admin",12,"male","no"\n',
#  '"295","admin",8,"male","no"\n',
#  '"296","admin",12,"male","no"\n',
#  '"297","admin",12,"female","no"\n',
#  '"298","admin",12,"female","no"\n',
#  '"299","admin",15,"female","no"\n',
#  '"300","admin",16,"male","yes"\n',
#  '"301","admin",12,"male","yes"\n',
#  '"302","admin",8,"male","yes"\n',
#  '"303","custodial",12,"male","yes"\n',
#  '"304","admin",15,"female","yes"\n',
#  '"305","custodial",12,"male","no"\n',
#  '"306","admin",15,"male","no"\n',
#  '"307","manage",16,"male","no"\n',
#  '"308","admin",15,"male","no"\n',
#  '"309","admin",15,"male","no"\n',
#  '"310","admin",16,"male","no"\n',
#  '"311","admin",12,"female","no"\n',
#  '"312","admin",12,"female","no"\n',
#  '"313","admin",12,"female","no"\n',
#  '"314","admin",12,"female","no"\n',
#  '"315","admin",12,"female","no"\n',
#  '"316","admin",15,"male","yes"\n',
#  '"317","admin",12,"male","yes"\n',
#  '"318","manage",16,"male","no"\n',
#  '"319","admin",15,"male","no"\n',
#  '"320","admin",12,"male","no"\n',
#  '"321","admin",12,"female","no"\n',
#  '"322","admin",12,"female","no"\n',
#  '"323","admin",15,"female","no"\n',
#  '"324","admin",12,"female","no"\n',
#  '"325","admin",8,"female","no"\n',
#  '"326","custodial",8,"male","yes"\n',
#  '"327","admin",12,"male","yes"\n',
#  '"328","manage",18,"male","no"\n',
#  '"329","manage",18,"male","no"\n',
#  '"330","admin",15,"male","no"\n',
#  '"331","admin",12,"female","no"\n',
#  '"332","admin",16,"female","no"\n',
#  '"333","admin",15,"female","no"\n',
#  '"334","admin",12,"female","yes"\n',
#  '"335","custodial",8,"male","no"\n',
#  '"336","manage",16,"male","no"\n',
#  '"337","admin",12,"female","no"\n',
#  '"338","admin",8,"female","no"\n',
#  '"339","admin",8,"female","no"\n',
#  '"340","admin",8,"female","no"\n',
#  '"341","manage",12,"male","yes"\n',
#  '"342","admin",12,"female","yes"\n',
#  '"343","manage",16,"male","no"\n',
#  '"344","admin",12,"male","no"\n',
#  '"345","admin",12,"female","no"\n',
#  '"346","admin",15,"female","no"\n',
#  '"347","admin",12,"female","no"\n',
#  '"348","manage",16,"female","no"\n',
#  '"349","admin",17,"female","no"\n',
#  '"350","admin",12,"female","no"\n',
#  '"351","admin",12,"female","no"\n',
#  '"352","admin",8,"female","no"\n',
#  '"353","custodial",12,"male","yes"\n',
#  '"354","admin",12,"female","yes"\n',
#  '"355","admin",15,"male","no"\n',
#  '"356","admin",15,"male","no"\n',
#  '"357","admin",8,"female","no"\n',
#  '"358","admin",15,"female","no"\n',
#  '"359","admin",12,"female","no"\n',
#  '"360","admin",12,"female","no"\n',
#  '"361","admin",12,"female","no"\n',
#  '"362","admin",8,"female","no"\n',
#  '"363","admin",16,"male","yes"\n',
#  '"364","admin",12,"female","yes"\n',
#  '"365","admin",8,"female","yes"\n',
#  '"366","admin",12,"female","yes"\n',
#  '"367","admin",12,"female","yes"\n',
#  '"368","admin",12,"female","yes"\n',
#  '"369","admin",14,"male","no"\n',
#  '"370","admin",16,"female","no"\n',
#  '"371","manage",16,"female","no"\n',
#  '"372","admin",15,"male","no"\n',
#  '"373","admin",12,"male","no"\n',
#  '"374","admin",15,"male","no"\n',
#  '"375","admin",12,"male","no"\n',
#  '"376","admin",15,"male","no"\n',
#  '"377","admin",15,"male","no"\n',
#  '"378","admin",8,"female","no"\n',
#  '"379","admin",8,"female","no"\n',
#  '"380","admin",12,"female","no"\n',
#  '"381","admin",17,"male","yes"\n',
#  '"382","admin",12,"male","yes"\n',
#  '"383","manage",17,"male","yes"\n',
#  '"384","admin",12,"female","yes"\n',
#  '"385","custodial",12,"male","no"\n',
#  '"386","custodial",8,"male","no"\n',
#  '"387","manage",19,"male","no"\n',
#  '"388","admin",14,"male","no"\n',
#  '"389","manage",19,"male","no"\n',
#  '"390","admin",15,"female","no"\n',
#  '"391","admin",12,"female","no"\n',
#  '"392","admin",12,"female","no"\n',
#  '"393","admin",12,"female","no"\n',
#  '"394","admin",8,"female","no"\n',
#  '"395","admin",12,"female","no"\n',
#  '"396","admin",12,"female","no"\n',
#  '"397","admin",12,"female","no"\n',
#  '"398","admin",12,"female","no"\n',
#  '"399","admin",12,"female","no"\n',
#  '"400","admin",12,"female","no"\n',
#  '"401","admin",12,"female","no"\n',
#  '"402","admin",12,"female","no"\n',
#  '"403","admin",12,"female","yes"\n',
#  '"404","admin",12,"female","yes"\n',
#  '"405","admin",12,"female","yes"\n',
#  '"406","manage",17,"male","no"\n',
#  '"407","admin",15,"male","no"\n',
#  '"408","manage",19,"male","no"\n',
#  '"409","admin",19,"male","no"\n',
#  '"410","admin",8,"female","no"\n',
#  '"411","admin",12,"female","no"\n',
#  '"412","admin",12,"female","no"\n',
#  '"413","manage",16,"female","no"\n',
#  '"414","custodial",8,"male","yes"\n',
#  '"415","admin",15,"male","yes"\n',
#  '"416","admin",15,"male","no"\n',
#  '"417","admin",15,"male","no"\n',
#  '"418","admin",15,"male","no"\n',
#  '"419","admin",15,"male","no"\n',
#  '"420","manage",19,"male","no"\n',
#  '"421","admin",15,"male","no"\n',
#  '"422","admin",15,"male","no"\n',
#  '"423","admin",12,"female","no"\n',
#  '"424","admin",15,"female","no"\n',
#  '"425","admin",12,"female","no"\n',
#  '"426","admin",16,"male","yes"\n',
#  '"427","admin",8,"male","yes"\n',
#  '"428","admin",15,"male","yes"\n',
#  '"429","custodial",8,"male","yes"\n',
#  '"430","manage",19,"male","yes"\n',
#  '"431","manage",18,"male","no"\n',
#  '"432","admin",12,"male","no"\n',
#  '"433","admin",12,"male","no"\n',
#  '"434","admin",16,"male","no"\n',
#  '"435","admin",15,"male","no"\n',
#  '"436","admin",12,"male","no"\n',
#  '"437","admin",8,"male","no"\n',
#  '"438","admin",15,"male","no"\n',
#  '"439","admin",12,"female","no"\n',
#  '"440","admin",8,"female","no"\n',
#  '"441","admin",15,"female","no"\n',
#  '"442","admin",12,"female","no"\n',
#  '"443","admin",8,"female","no"\n',
#  '"444","admin",12,"female","no"\n',
#  '"445","admin",15,"male","yes"\n',
#  '"446","manage",16,"male","yes"\n',
#  '"447","admin",15,"male","yes"\n',
#  '"448","admin",12,"female","yes"\n',
#  '"449","manage",16,"male","no"\n',
#  '"450","manage",19,"male","no"\n',
#  '"451","admin",15,"male","no"\n',
#  '"452","admin",12,"male","no"\n',
#  '"453","admin",15,"male","no"\n',
#  '"454","manage",19,"male","no"\n',
#  '"455","manage",16,"male","no"\n',
#  '"456","manage",19,"male","no"\n',
#  '"457","admin",15,"male","no"\n',
#  '"458","manage",19,"male","no"\n',
#  '"459","admin",12,"female","no"\n',
#  '"460","admin",12,"female","no"\n',
#  '"461","admin",8,"female","no"\n',
#  '"462","manage",16,"female","no"\n',
#  '"463","admin",15,"female","no"\n',
#  '"464","manage",19,"male","no"\n',
#  '"465","admin",12,"male","no"\n',
#  '"466","admin",12,"female","no"\n',
#  '"467","admin",16,"female","no"\n',
#  '"468","manage",16,"female","no"\n',
#  '"469","admin",15,"female","no"\n',
#  '"470","admin",12,"male","yes"\n',
#  '"471","admin",15,"male","yes"\n',
#  '"472","admin",15,"male","no"\n',
#  '"473","admin",12,"female","no"\n',
#  '"474","admin",12,"female","no"\n']

# %%
assert len(dataset) >= 474, "Hai caricato correttamente il dataset?"

assert len(dataset) == 474, "Hai eliminato la prima riga?"

assert type(dataset[0]) == str, "Hai caricato correttamente gli elementi del dataset?"

# %%
dataset = [elem.replace('"' , '').replace('\n' , '') for elem in dataset]
dataset
# Out:
# ['1,manage,15,male,no',
#  '2,admin,16,male,no',
#  '3,admin,12,female,no',
#  '4,admin,8,female,no',
#  '5,admin,15,male,no',
#  '6,admin,15,male,no',
#  '7,admin,15,male,no',
#  '8,admin,12,female,no',
#  '9,admin,15,female,no',
#  '10,admin,12,female,no',
#  '11,admin,16,female,no',
#  '12,admin,8,male,yes',
#  '13,admin,15,male,yes',
#  '14,admin,15,female,yes',
#  '15,admin,12,male,no',
#  '16,admin,12,male,no',
#  '17,admin,15,male,no',
#  '18,manage,16,male,no',
#  '19,admin,12,male,no',
#  '20,admin,12,female,no',
#  '21,admin,16,female,no',
#  '22,admin,12,male,yes',
#  '23,admin,15,female,yes',
#  '24,admin,12,female,yes',
#  '25,admin,15,female,yes',
#  '26,admin,15,male,no',
#  '27,manage,19,male,no',
#  '28,admin,15,male,no',
#  '29,manage,19,male,no',
#  '30,admin,15,male,no',
#  '31,admin,12,male,no',
#  '32,manage,19,male,no',
#  '33,admin,15,male,no',
#  '34,manage,19,male,no',
#  '35,manage,17,male,no',
#  '36,admin,8,female,no',
#  '37,admin,12,male,yes',
#  '38,admin,15,male,yes',
#  '39,admin,16,male,yes',
#  '40,admin,15,female,yes',
#  '41,admin,12,female,yes',
#  '42,admin,15,male,no',
#  '43,admin,12,male,no',
#  '44,admin,8,male,no',
#  '45,custodial,12,male,no',
#  '46,admin,15,female,no',
#  '47,admin,12,female,no',
#  '48,custodial,12,male,no',
#  '49,admin,15,male,no',
#  '50,manage,16,male,no',
#  '51,admin,12,male,no',
#  '52,admin,15,male,no',
#  '53,manage,18,male,no',
#  '54,admin,12,male,no',
#  '55,admin,12,male,no',
#  '56,admin,15,male,no',
#  '57,admin,15,male,no',
#  '58,admin,15,female,no',
#  '59,admin,15,male,yes',
#  '60,admin,12,male,yes',
#  '61,admin,8,male,yes',
#  '62,manage,16,male,no',
#  '63,manage,17,male,no',
#  '64,manage,16,male,no',
#  '65,admin,8,male,no',
#  '66,manage,19,male,no',
#  '67,manage,16,male,no',
#  '68,manage,16,male,no',
#  '69,manage,16,male,no',
#  '70,admin,15,male,no',
#  '71,manage,17,male,no',
#  '72,admin,16,female,no',
#  '73,admin,12,female,no',
#  '74,admin,15,female,no',
#  '75,admin,15,female,no',
#  '76,admin,15,female,no',
#  '77,admin,12,female,no',
#  '78,admin,12,female,no',
#  '79,admin,16,female,no',
#  '80,admin,16,female,no',
#  '81,admin,12,female,no',
#  '82,admin,12,female,yes',
#  '83,admin,12,female,yes',
#  '84,admin,8,female,yes',
#  '85,admin,15,male,no',
#  '86,admin,15,male,no',
#  '87,admin,12,male,no',
#  '88,manage,19,male,no',
#  '89,manage,19,male,no',
#  '90,admin,8,female,no',
#  '91,admin,12,female,no',
#  '92,admin,8,female,no',
#  '93,admin,12,female,no',
#  '94,admin,12,female,no',
#  '95,admin,12,female,no',
#  '96,custodial,8,male,yes',
#  '97,admin,17,male,yes',
#  '98,custodial,8,male,yes',
#  '99,admin,12,female,yes',
#  '100,manage,18,male,no',
#  '101,manage,16,male,no',
#  '102,admin,14,male,no',
#  '103,manage,19,male,no',
#  '104,admin,15,male,no',
#  '105,admin,15,male,no',
#  '106,manage,19,male,no',
#  '107,admin,12,female,no',
#  '108,admin,12,female,no',
#  '109,admin,12,male,yes',
#  '110,admin,15,male,yes',
#  '111,custodial,12,male,yes',
#  '112,custodial,12,male,yes',
#  '113,manage,16,male,no',
#  '114,admin,14,male,no',
#  '115,admin,15,male,no',
#  '116,admin,15,male,no',
#  '117,admin,12,female,no',
#  '118,admin,12,female,no',
#  '119,admin,12,female,no',
#  '120,manage,16,female,no',
#  '121,admin,15,female,no',
#  '122,admin,15,female,no',
#  '123,admin,12,female,no',
#  '124,admin,16,female,no',
#  '125,admin,12,male,yes',
#  '126,custodial,15,male,yes',
#  '127,custodial,12,male,yes',
#  '128,admin,12,female,yes',
#  '129,manage,17,male,no',
#  '130,manage,20,male,no',
#  '131,admin,15,male,no',
#  '132,admin,12,male,no',
#  '133,admin,15,male,no',
#  '134,manage,16,female,no',
#  '135,admin,12,female,no',
#  '136,admin,12,male,no',
#  '137,manage,21,male,no',
#  '138,admin,12,male,no',
#  '139,admin,8,female,no',
#  '140,admin,12,female,no',
#  '141,admin,15,female,no',
#  '142,admin,12,female,no',
#  '143,admin,12,female,no',
#  '144,admin,8,female,no',
#  '145,admin,12,male,yes',
#  '146,admin,18,male,yes',
#  '147,admin,15,male,yes',
#  '148,admin,15,female,yes',
#  '149,admin,12,male,no',
#  '150,admin,12,male,no',
#  '151,manage,16,male,no',
#  '152,custodial,8,male,no',
#  '153,admin,12,female,no',
#  '154,admin,12,female,no',
#  '155,admin,15,male,yes',
#  '156,admin,15,male,yes',
#  '157,admin,12,female,yes',
#  '158,admin,12,female,yes',
#  '159,admin,16,female,yes',
#  '160,manage,16,male,no',
#  '161,admin,16,male,no',
#  '162,manage,16,male,no',
#  '163,admin,15,male,no',
#  '164,admin,15,female,no',
#  '165,admin,15,female,no',
#  '166,admin,12,female,no',
#  '167,admin,12,female,no',
#  '168,manage,16,female,no',
#  '169,admin,12,male,yes',
#  '170,admin,12,male,yes',
#  '171,admin,12,male,yes',
#  '172,admin,15,female,yes',
#  '173,manage,20,male,no',
#  '174,custodial,8,male,no',
#  '175,admin,8,male,no',
#  '176,admin,16,female,no',
#  '177,admin,12,female,no',
#  '178,admin,12,female,no',
#  '179,admin,12,male,yes',
#  '180,admin,12,female,yes',
#  '181,admin,12,female,yes',
#  '182,admin,12,female,yes',
#  '183,admin,15,male,no',
#  '184,admin,15,male,no',
#  '185,custodial,8,male,no',
#  '186,admin,15,male,no',
#  '187,manage,16,male,no',
#  '188,admin,12,female,no',
#  '189,admin,12,female,no',
#  '190,admin,8,female,no',
#  '191,admin,12,female,no',
#  '192,admin,12,male,yes',
#  '193,admin,12,female,yes',
#  '194,admin,15,female,yes',
#  '195,admin,12,female,yes',
#  '196,admin,16,female,yes',
#  '197,manage,15,male,no',
#  '198,manage,19,male,no',
#  '199,manage,16,male,no',
#  '200,manage,17,male,no',
#  '201,admin,12,male,no',
#  '202,admin,15,male,no',
#  '203,admin,12,male,no',
#  '204,admin,15,male,no',
#  '205,manage,16,male,no',
#  '206,custodial,12,male,no',
#  '207,admin,15,male,no',
#  '208,admin,12,female,no',
#  '209,admin,8,female,no',
#  '210,admin,15,male,yes',
#  '211,admin,15,male,yes',
#  '212,admin,15,male,yes',
#  '213,custodial,8,male,yes',
#  '214,admin,12,female,yes',
#  '215,admin,12,female,yes',
#  '216,admin,15,male,no',
#  '217,admin,16,male,no',
#  '218,admin,15,male,no',
#  '219,admin,12,male,no',
#  '220,admin,12,male,no',
#  '221,admin,12,female,no',
#  '222,admin,15,female,no',
#  '223,admin,8,female,no',
#  '224,admin,12,female,no',
#  '225,admin,15,female,no',
#  '226,admin,16,female,no',
#  '227,admin,12,female,no',
#  '228,admin,15,female,no',
#  '229,admin,12,female,no',
#  '230,admin,15,male,yes',
#  '231,manage,16,male,no',
#  '232,manage,19,male,no',
#  '233,admin,15,male,no',
#  '234,admin,15,male,no',
#  '235,manage,19,male,no',
#  '236,admin,8,female,no',
#  '237,admin,12,female,no',
#  '238,admin,12,female,no',
#  '239,admin,12,female,no',
#  '240,manage,16,female,no',
#  '241,admin,8,female,no',
#  '242,admin,12,female,no',
#  '243,admin,12,female,no',
#  '244,admin,8,female,no',
#  '245,admin,12,female,no',
#  '246,admin,12,female,no',
#  '247,admin,12,female,no',
#  '248,admin,12,female,no',
#  '249,admin,12,female,no',
#  '250,admin,15,female,no',
#  '251,admin,12,female,no',
#  '252,admin,12,male,yes',
#  '253,admin,8,female,yes',
#  '254,manage,18,male,no',
#  '255,custodial,12,male,no',
#  '256,manage,19,male,no',
#  '257,manage,19,male,no',
#  '258,admin,8,male,no',
#  '259,admin,12,female,no',
#  '260,admin,12,female,no',
#  '261,admin,12,female,no',
#  '262,admin,12,female,no',
#  '263,admin,12,female,no',
#  '264,admin,12,female,no',
#  '265,admin,12,female,no',
#  '266,admin,16,female,no',
#  '267,admin,12,female,no',
#  '268,admin,12,male,yes',
#  '269,admin,15,male,no',
#  '270,admin,15,male,no',
#  '271,admin,15,male,no',
#  '272,admin,18,male,no',
#  '273,custodial,12,male,no',
#  '274,manage,16,male,no',
#  '275,admin,12,male,no',
#  '276,manage,16,male,no',
#  '277,manage,16,female,no',
#  '278,admin,8,female,no',
#  '279,admin,12,female,no',
#  '280,admin,12,female,no',
#  '281,custodial,8,male,yes',
#  '282,admin,14,male,yes',
#  '283,manage,19,male,no',
#  '284,manage,19,male,no',
#  '285,custodial,8,male,no',
#  '286,manage,15,male,no',
#  '287,admin,16,male,no',
#  '288,manage,15,male,no',
#  '289,manage,17,male,no',
#  '290,manage,18,male,no',
#  '291,custodial,12,male,no',
#  '292,admin,14,male,no',
#  '293,admin,15,male,no',
#  '294,admin,12,male,no',
#  '295,admin,8,male,no',
#  '296,admin,12,male,no',
#  '297,admin,12,female,no',
#  '298,admin,12,female,no',
#  '299,admin,15,female,no',
#  '300,admin,16,male,yes',
#  '301,admin,12,male,yes',
#  '302,admin,8,male,yes',
#  '303,custodial,12,male,yes',
#  '304,admin,15,female,yes',
#  '305,custodial,12,male,no',
#  '306,admin,15,male,no',
#  '307,manage,16,male,no',
#  '308,admin,15,male,no',
#  '309,admin,15,male,no',
#  '310,admin,16,male,no',
#  '311,admin,12,female,no',
#  '312,admin,12,female,no',
#  '313,admin,12,female,no',
#  '314,admin,12,female,no',
#  '315,admin,12,female,no',
#  '316,admin,15,male,yes',
#  '317,admin,12,male,yes',
#  '318,manage,16,male,no',
#  '319,admin,15,male,no',
#  '320,admin,12,male,no',
#  '321,admin,12,female,no',
#  '322,admin,12,female,no',
#  '323,admin,15,female,no',
#  '324,admin,12,female,no',
#  '325,admin,8,female,no',
#  '326,custodial,8,male,yes',
#  '327,admin,12,male,yes',
#  '328,manage,18,male,no',
#  '329,manage,18,male,no',
#  '330,admin,15,male,no',
#  '331,admin,12,female,no',
#  '332,admin,16,female,no',
#  '333,admin,15,female,no',
#  '334,admin,12,female,yes',
#  '335,custodial,8,male,no',
#  '336,manage,16,male,no',
#  '337,admin,12,female,no',
#  '338,admin,8,female,no',
#  '339,admin,8,female,no',
#  '340,admin,8,female,no',
#  '341,manage,12,male,yes',
#  '342,admin,12,female,yes',
#  '343,manage,16,male,no',
#  '344,admin,12,male,no',
#  '345,admin,12,female,no',
#  '346,admin,15,female,no',
#  '347,admin,12,female,no',
#  '348,manage,16,female,no',
#  '349,admin,17,female,no',
#  '350,admin,12,female,no',
#  '351,admin,12,female,no',
#  '352,admin,8,female,no',
#  '353,custodial,12,male,yes',
#  '354,admin,12,female,yes',
#  '355,admin,15,male,no',
#  '356,admin,15,male,no',
#  '357,admin,8,female,no',
#  '358,admin,15,female,no',
#  '359,admin,12,female,no',
#  '360,admin,12,female,no',
#  '361,admin,12,female,no',
#  '362,admin,8,female,no',
#  '363,admin,16,male,yes',
#  '364,admin,12,female,yes',
#  '365,admin,8,female,yes',
#  '366,admin,12,female,yes',
#  '367,admin,12,female,yes',
#  '368,admin,12,female,yes',
#  '369,admin,14,male,no',
#  '370,admin,16,female,no',
#  '371,manage,16,female,no',
#  '372,admin,15,male,no',
#  '373,admin,12,male,no',
#  '374,admin,15,male,no',
#  '375,admin,12,male,no',
#  '376,admin,15,male,no',
#  '377,admin,15,male,no',
#  '378,admin,8,female,no',
#  '379,admin,8,female,no',
#  '380,admin,12,female,no',
#  '381,admin,17,male,yes',
#  '382,admin,12,male,yes',
#  '383,manage,17,male,yes',
#  '384,admin,12,female,yes',
#  '385,custodial,12,male,no',
#  '386,custodial,8,male,no',
#  '387,manage,19,male,no',
#  '388,admin,14,male,no',
#  '389,manage,19,male,no',
#  '390,admin,15,female,no',
#  '391,admin,12,female,no',
#  '392,admin,12,female,no',
#  '393,admin,12,female,no',
#  '394,admin,8,female,no',
#  '395,admin,12,female,no',
#  '396,admin,12,female,no',
#  '397,admin,12,female,no',
#  '398,admin,12,female,no',
#  '399,admin,12,female,no',
#  '400,admin,12,female,no',
#  '401,admin,12,female,no',
#  '402,admin,12,female,no',
#  '403,admin,12,female,yes',
#  '404,admin,12,female,yes',
#  '405,admin,12,female,yes',
#  '406,manage,17,male,no',
#  '407,admin,15,male,no',
#  '408,manage,19,male,no',
#  '409,admin,19,male,no',
#  '410,admin,8,female,no',
#  '411,admin,12,female,no',
#  '412,admin,12,female,no',
#  '413,manage,16,female,no',
#  '414,custodial,8,male,yes',
#  '415,admin,15,male,yes',
#  '416,admin,15,male,no',
#  '417,admin,15,male,no',
#  '418,admin,15,male,no',
#  '419,admin,15,male,no',
#  '420,manage,19,male,no',
#  '421,admin,15,male,no',
#  '422,admin,15,male,no',
#  '423,admin,12,female,no',
#  '424,admin,15,female,no',
#  '425,admin,12,female,no',
#  '426,admin,16,male,yes',
#  '427,admin,8,male,yes',
#  '428,admin,15,male,yes',
#  '429,custodial,8,male,yes',
#  '430,manage,19,male,yes',
#  '431,manage,18,male,no',
#  '432,admin,12,male,no',
#  '433,admin,12,male,no',
#  '434,admin,16,male,no',
#  '435,admin,15,male,no',
#  '436,admin,12,male,no',
#  '437,admin,8,male,no',
#  '438,admin,15,male,no',
#  '439,admin,12,female,no',
#  '440,admin,8,female,no',
#  '441,admin,15,female,no',
#  '442,admin,12,female,no',
#  '443,admin,8,female,no',
#  '444,admin,12,female,no',
#  '445,admin,15,male,yes',
#  '446,manage,16,male,yes',
#  '447,admin,15,male,yes',
#  '448,admin,12,female,yes',
#  '449,manage,16,male,no',
#  '450,manage,19,male,no',
#  '451,admin,15,male,no',
#  '452,admin,12,male,no',
#  '453,admin,15,male,no',
#  '454,manage,19,male,no',
#  '455,manage,16,male,no',
#  '456,manage,19,male,no',
#  '457,admin,15,male,no',
#  '458,manage,19,male,no',
#  '459,admin,12,female,no',
#  '460,admin,12,female,no',
#  '461,admin,8,female,no',
#  '462,manage,16,female,no',
#  '463,admin,15,female,no',
#  '464,manage,19,male,no',
#  '465,admin,12,male,no',
#  '466,admin,12,female,no',
#  '467,admin,16,female,no',
#  '468,manage,16,female,no',
#  '469,admin,15,female,no',
#  '470,admin,12,male,yes',
#  '471,admin,15,male,yes',
#  '472,admin,15,male,no',
#  '473,admin,12,female,no',
#  '474,admin,12,female,no']

# %%
assert all('"' not in s for s in dataset), "Hai eliminato tutti i doppi apici?"

assert all('\n' not in s for s in dataset), "Hai eliminato tutte le newline?"

assert len(dataset) >= 474, "Hai modificato correttamente il dataset?"

# %%
def abbrv(s):
    if s.isalpha() and len(s)>4 and s[len(s)-1]!='.':
        return s[:3]+'.'
    else:
        return s

# %%
'ciao'.isalpha()
# Out:
# True

# %%
'ciao'.isalnum()
# Out:
# True

# %%
abbrv('female')
# Out:
# 'fem.'

# %%
assert abbrv('extra10')=='extra10', "Hai verificato la condizione sui caratteri?"

assert abbrv('male')=='male', "Hai verificato la condizione sulla lunghezza?"

assert abbrv('manage.')=='manage.', "Hai verificato la condizione sul punto?"

assert abbrv('female')=='fem.', "Hai trasformato correttamente la stringa?"

# %%
def f(s):
    return ','.join(elem for elem in map(lambda x: abbrv(x), s.split(',')))
    return ','.join(abbrv(i) for i in s.split(','))

# %%
f("1,manage,15,male,no")
# Out:
# '1,man.,15,male,no'

# %%
assert f("1,manage,15,male,no")=="1,man.,15,male,no", "Hai definito correttamente la funzione?"

# %%
dataset_map = map(f,dataset)
dataset_map

# %%
assert type(dataset_map) == map, "Hai creato correttamente la map?"

# %%
dataset_filter = filter(lambda x: len(x)==20,dataset_map)

# %%
assert type(dataset_filter) == filter, "Hai costruito correttamente il filtro?"

# %%
filtered_dataset = list(dataset_filter)
filtered_dataset
# Out:
# ['109,adm.,12,male,yes',
#  '110,adm.,15,male,yes',
#  '111,cus.,12,male,yes',
#  '112,cus.,12,male,yes',
#  '125,adm.,12,male,yes',
#  '126,cus.,15,male,yes',
#  '127,cus.,12,male,yes',
#  '128,adm.,12,fem.,yes',
#  '145,adm.,12,male,yes',
#  '146,adm.,18,male,yes',
#  '147,adm.,15,male,yes',
#  '148,adm.,15,fem.,yes',
#  '155,adm.,15,male,yes',
#  '156,adm.,15,male,yes',
#  '157,adm.,12,fem.,yes',
#  '158,adm.,12,fem.,yes',
#  '159,adm.,16,fem.,yes',
#  '169,adm.,12,male,yes',
#  '170,adm.,12,male,yes',
#  '171,adm.,12,male,yes',
#  '172,adm.,15,fem.,yes',
#  '179,adm.,12,male,yes',
#  '180,adm.,12,fem.,yes',
#  '181,adm.,12,fem.,yes',
#  '182,adm.,12,fem.,yes',
#  '192,adm.,12,male,yes',
#  '193,adm.,12,fem.,yes',
#  '194,adm.,15,fem.,yes',
#  '195,adm.,12,fem.,yes',
#  '196,adm.,16,fem.,yes',
#  '210,adm.,15,male,yes',
#  '211,adm.,15,male,yes',
#  '212,adm.,15,male,yes',
#  '214,adm.,12,fem.,yes',
#  '215,adm.,12,fem.,yes',
#  '230,adm.,15,male,yes',
#  '252,adm.,12,male,yes',
#  '268,adm.,12,male,yes',
#  '282,adm.,14,male,yes',
#  '300,adm.,16,male,yes',
#  '301,adm.,12,male,yes',
#  '303,cus.,12,male,yes',
#  '304,adm.,15,fem.,yes',
#  '316,adm.,15,male,yes',
#  '317,adm.,12,male,yes',
#  '327,adm.,12,male,yes',
#  '334,adm.,12,fem.,yes',
#  '341,man.,12,male,yes',
#  '342,adm.,12,fem.,yes',
#  '353,cus.,12,male,yes',
#  '354,adm.,12,fem.,yes',
#  '363,adm.,16,male,yes',
#  '364,adm.,12,fem.,yes',
#  '366,adm.,12,fem.,yes',
#  '367,adm.,12,fem.,yes',
#  '368,adm.,12,fem.,yes',
#  '381,adm.,17,male,yes',
#  '382,adm.,12,male,yes',
#  '383,man.,17,male,yes',
#  '384,adm.,12,fem.,yes',
#  '403,adm.,12,fem.,yes',
#  '404,adm.,12,fem.,yes',
#  '405,adm.,12,fem.,yes',
#  '415,adm.,15,male,yes',
#  '426,adm.,16,male,yes',
#  '428,adm.,15,male,yes',
#  '430,man.,19,male,yes',
#  '445,adm.,15,male,yes',
#  '446,man.,16,male,yes',
#  '447,adm.,15,male,yes',
#  '448,adm.,12,fem.,yes',
#  '470,adm.,12,male,yes',
#  '471,adm.,15,male,yes']

# %%
assert all(len(s)==20 for s in filtered_dataset), "Hai applicato correttamente la condizione di filtro?"

# %%
import re
low_education = [elem for elem in dataset if re.fullmatch(r'.*,\d,.*', elem)]
low_education[:10]
# Out:
# ['4,admin,8,female,no',
#  '12,admin,8,male,yes',
#  '36,admin,8,female,no',
#  '44,admin,8,male,no',
#  '61,admin,8,male,yes',
#  '65,admin,8,male,no',
#  '84,admin,8,female,yes',
#  '90,admin,8,female,no',
#  '92,admin,8,female,no',
#  '96,custodial,8,male,yes']

# %%
assert 60>len(low_education)>50, "Hai filtrato correttamente gli elementi della lista?"

assert all(',8,' in s for s in low_education), "Hai utilizzato l'espressione regolare corretta?"

assert all('male' in s for s in low_education), "Hai estratto l'intera stringa?"
